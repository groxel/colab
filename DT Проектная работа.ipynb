# %%
# https://github.com/groxel/colab/blob/main/data_set.xlsx

import pandas as pd #импортируем библиотеку pandas

# загружаем таблицу формата xlsx
data = pd.read_excel(io = "https://github.com/groxel/colab/raw/refs/heads/main/data_set.xlsx", header = 3)
# Out:
#    № Наименование компании  Номер  Количество контрагентов  \
# 0  1           Одуванчик 1      1                       17
# 1  2           Одуванчик 2      2                        8
# 2  3           Одуванчик 3      3                       14
# 3  4           Одуванчик 4      4                        5
# 4  5           Одуванчик 5      5                        6
#
#    Количество контрактов  Сумма договоров, тыс. руб.  \
# 0                     24                 49753000.00
# 1                     19                  8627121.00
# 2                     16                  3668000.00
# 3                     27                  9575238.00
# 4                     33                 30537299.76
#
#    полученные деньги (авансы), тыс. руб.  остаток к получению, тыс. руб.  \
# 0                            29790000.00                     13763000.00
# 1                             5743374.00                      2883747.00
# ...

# %%
data.head() # выводим первые пять строчек
# Out:
#    № Наименование компании  Номер  Количество контрагентов  \
# 0  1           Одуванчик 1      1                       17
# 1  2           Одуванчик 2      2                        8
# 2  3           Одуванчик 3      3                       14
# 3  4           Одуванчик 4      4                        5
# 4  5           Одуванчик 5      5                        6
#
#    Количество контрактов  Сумма договоров, тыс. руб.  \
# 0                     24                 49753000.00
# 1                     19                  8627121.00
# 2                     16                  3668000.00
# 3                     27                  9575238.00
# 4                     33                 30537299.76
#
#    полученные деньги (авансы), тыс. руб.  остаток к получению, тыс. руб.  \
# 0                            29790000.00                     13763000.00
# 1                             5743374.00                      2883747.00
# ...

# %%
# число строк, число столбцов
data.shape
# Out:
# (100, 24)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   №                                      100 non-null    int64
#  1   Наименование компании                  100 non-null    object
#  2   Номер                                  100 non-null    int64
#  3   Количество контрагентов                100 non-null    int64
#  4   Количество контрактов                  100 non-null    int64
#  5   Сумма договоров, тыс. руб.             100 non-null    float64
#  6   полученные деньги (авансы), тыс. руб.  100 non-null    float64
#  7   остаток к получению, тыс. руб.         100 non-null    float64
#  8   1150                                   100 non-null    object
#  9   !!! 1170                               100 non-null    object
# ...
